# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import pickle

# %%
anime_data = pd.read_csv('../Datasets/anilist.csv')

# %%
selected_features = ['format','genres','seasonYear','description','studio','streamingPlatform','averageScore','popularity','mainCharacters']

# %%
for feature in selected_features:
    anime_data[feature] = anime_data[feature].astype(str)
anime_data.head()
# Out:
#        id                             title averageScore  episodes    status  \
# 0  154587     Frieren: Beyond Journey’s End           91      28.0  FINISHED
# 1  114129           Gintama: THE VERY FINAL           91       1.0  FINISHED
# 2   20996                  Gintama Season 4           90      51.0  FINISHED
# 3  182469              ONE PIECE FAN LETTER           90       1.0  FINISHED
# 4    5114  Fullmetal Alchemist: Brotherhood           90      64.0  FINISHED
#
#     format                             genres  season seasonYear  \
# 0       TV          Adventure, Drama, Fantasy    FALL     2023.0
# 1    MOVIE      Action, Comedy, Drama, Sci-Fi  WINTER     2021.0
# 2       TV      Action, Comedy, Drama, Sci-Fi  SPRING     2015.0
# 3  SPECIAL         Action, Adventure, Fantasy    FALL     2024.0
# 4       TV  Action, Adventure, Drama, Fantasy  SPRING     2009.0
#
#   streamingPlatform popularity  \
# 0       Crunchyroll     333256
# 1       Crunchyroll      47089
# ...

# %%
combined_features = anime_data[selected_features[0]]
for feature in selected_features[1:]:
    combined_features += ' ' + anime_data[feature]

# %%
vectroizer = TfidfVectorizer()

# %%
feature_vectors = vectroizer.fit_transform(combined_features)

# %%
similarty = cosine_similarity(feature_vectors)

# %%
anime_model = pickle.dump(similarty,open('../Models/similarity.sav','wb'))
